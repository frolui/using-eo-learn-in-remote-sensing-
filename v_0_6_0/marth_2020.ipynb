# %%
#fuck

# %%
from eolearn.core.eoworkflow import LinearWorkflow, Dependency
from eolearn.core.eodata import FeatureType

# %%
from sentinelhub import BBox, CRS

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
from eolearn.core import SaveToDisk, LoadFromDisk
from eolearn.io import S2L1CWCSInput, AddSen2CorClassificationFeature, DEMWCSInput, S2L2AWCSInput, L8L1CWCSInput

# %%
roi_bbox = BBox(bbox=[5.60, 52.68, 5.75, 52.63], crs=CRS.WGS84)
time_interval = ('2018-04-01', '2018-05-01')

# %%
layer = 'BANDS-S2-L1C'

input_task = S2L1CWCSInput(layer=layer,
                           resx='20m', resy='20m',
                           maxcc=.8, time_difference=datetime.timedelta(hours=2))

add_ndvi = S2L1CWCSInput(layer='NDVI')

add_dem = DEMWCSInput(layer='DEM')

add_l2a = S2L2AWCSInput(layer='BANDS-S2-L2A')

add_sen2cor = AddSen2CorClassificationFeature('SCL', layer='BANDS-S2-L2A')

#save = SaveToDisk('io_example', overwrite_permission=2, compress_level=1)

# %%
workflow = LinearWorkflow(input_task, add_ndvi, add_l2a, add_sen2cor, add_dem, save)

result = workflow.execute({input_task: {'bbox': roi_bbox, 'time_interval': time_interval},
                           save: {'eopatch_folder': 'eopatch'}})
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\download\handlers.py in new_download_func(self, request)
#      21         try:
# ---> 22             return download_func(self, request)
#      23         except requests.HTTPError as exception:
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\download\client.py in _execute_download(self, request)
#     129
# --> 130         response.raise_for_status()
#     131         LOGGER.debug('Successful download from %s', request.url)
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\requests\models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 400 Client Error: Bad Request for url: https://services.sentinel-hub.com/ogc/wfs/4d2333cd-27aa-43ed-9b6e-60240a6f6787?SERVICE=wfs&REQUEST=GetFeature&TYPENAMES=DSS2&BBOX=52.63%2C5.6%2C52.68%2C5.75&OUTPUTFORMAT=application%2Fjson&SRSNAME=EPSG%3A4326&TIME=2018-04-01T00%3A00%3A00%2F2018-05-01T23%3A59%3A59&MAXCC=80.0&MAXFEATURES=100&FEATURE_OFFSET=0
#
# The above exception was the direct cause of the following exception:
#
# DownloadFailedException                   Traceback (most recent call last)
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\eolearn\core\eotask.py in _execute_handling(self, *eopatches, **kwargs)
#      71         try:
# ---> 72             return_value = self.execute(*eopatches, **kwargs)
#      73             self.private_task_config.end_time = datetime.datetime.now()
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\eolearn\io\sentinelhub_service.py in execute(self, eopatch, bbox, time_interval)
#     203         request = {ServiceType.WMS: WmsRequest,
# --> 204                    ServiceType.WCS: WcsRequest}[service_type](**request_params)
#     205
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\data_request.py in __init__(self, resx, resy, **kwargs)
#     494         """
# --> 495         super().__init__(service_type=ServiceType.WCS, size_x=resx, size_y=resy, **kwargs)
#     496
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\data_request.py in __init__(self, layer, bbox, time, service_type, data_source, size_x, size_y, maxcc, image_format, custom_url_params, time_difference, **kwargs)
#     303
# --> 304         super().__init__(SentinelHubDownloadClient, **kwargs)
#     305
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\data_request.py in __init__(self, download_client_class, data_folder, config, instance_id)
#      51         self.folder_list = []
# ---> 52         self.create_request()
#      53
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\data_request.py in create_request(self, reset_wfs_iterator)
#     332         ogc_service = OgcImageService(config=self.config)
# --> 333         self.download_list = ogc_service.get_request(self)
#     334         self.wfs_iterator = ogc_service.get_wfs_iterator()
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\ogc.py in get_request(self, request)
#      84                                 data_type=request.image_format, headers=SHConstants.HEADERS)
# ---> 85                 for date in self.get_dates(request)]
#      86
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\ogc.py in get_dates(self, request)
#     309
# --> 310         dates = self.wfs_iterator.get_dates()
#     311         dates = filter_times(dates, request.time_difference)
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\ogc.py in get_dates(self)
#     450
# --> 451         for tile_info in self:
#     452             if not tile_info['properties']['date']:  # could be True for custom (BYOC) data sources
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\ogc.py in __next__(self)
#     396         while self.index >= len(self.tile_list) and self.feature_offset is not None:
# --> 397             self._fetch_features()
#     398
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\ogc.py in _fetch_features(self)
#     426         LOGGER.debug("URL=%s", url)
# --> 427         response = get_json(url)
#     428
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\download\client.py in get_json(url, post_values, headers, download_client_class)
#     167
# --> 168     return download_client_class().download(request)
#     169
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\download\client.py in download(self, download_requests, max_threads, decode_data)
#      78                     traceback = sys.exc_info()[2]
# ---> 79                     raise download_exception.with_traceback(traceback)
#      80
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\download\client.py in download(self, download_requests, max_threads, decode_data)
#      74             try:
# ---> 75                 data_list.append(future.result())
#      76             except DownloadFailedException as download_exception:
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\concurrent\futures\_base.py in result(self, timeout)
#     424             elif self._state == FINISHED:
# --> 425                 return self.__get_result()
#     426
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\concurrent\futures\_base.py in __get_result(self)
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\concurrent\futures\thread.py in run(self)
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\download\client.py in _single_download(self, request, decode_data)
#      99
# --> 100         response_content = self._execute_download(request)
#     101
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\download\handlers.py in new_download_func(self, request)
#      43             try:
# ---> 44                 return download_func(self, request)
#      45             except requests.RequestException as exception:
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\download\handlers.py in new_download_func(self, request)
#      26
# ---> 27                 raise DownloadFailedException(_create_download_failed_message(exception, request.url)) from exception
#      28             raise exception from exception
#
# DownloadFailedException: Failed to download from:
# https://services.sentinel-hub.com/ogc/wfs/4d2333cd-27aa-43ed-9b6e-60240a6f6787?SERVICE=wfs&REQUEST=GetFeature&TYPENAMES=DSS2&BBOX=52.63%2C5.6%2C52.68%2C5.75&OUTPUTFORMAT=application%2Fjson&SRSNAME=EPSG%3A4326&TIME=2018-04-01T00%3A00%3A00%2F2018-05-01T23%3A59%3A59&MAXCC=80.0&MAXFEATURES=100&FEATURE_OFFSET=0
# with HTTPError:
# 400 Client Error: Bad Request for url: https://services.sentinel-hub.com/ogc/wfs/4d2333cd-27aa-43ed-9b6e-60240a6f6787?SERVICE=wfs&REQUEST=GetFeature&TYPENAMES=DSS2&BBOX=52.63%2C5.6%2C52.68%2C5.75&OUTPUTFORMAT=application%2Fjson&SRSNAME=EPSG%3A4326&TIME=2018-04-01T00%3A00%3A00%2F2018-05-01T23%3A59%3A59&MAXCC=80.0&MAXFEATURES=100&FEATURE_OFFSET=0
# Server response: "TYPENAME=DSS2 not found!"
#
# During handling of the above exception, another exception occurred:
#
# DownloadFailedException                   Traceback (most recent call last)
# <ipython-input-9-52b2104fd372> in <module>
#       2
#       3 result = workflow.execute({input_task: {'bbox': roi_bbox, 'time_interval': time_interval},
# ----> 4                            save: {'eopatch_folder': 'eopatch'}})
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\eolearn\core\eoworkflow.py in execute(self, input_args, monitor)
#     170         input_args = self.parse_input_args(input_args)
#     171
# --> 172         results = WorkflowResults(self._execute_tasks(input_args=input_args, out_degs=out_degs, monitor=monitor))
#     173
#     174         LOGGER.debug('Workflow finished with %s', repr(results))
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\eolearn\core\eoworkflow.py in _execute_tasks(self, input_args, out_degs, monitor)
#     208                                         input_args=input_args,
#     209                                         intermediate_results=intermediate_results,
# --> 210                                         monitor=monitor)
#     211
#     212             intermediate_results[dep] = result
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\eolearn\core\eoworkflow.py in _execute_task(self, dependency, input_args, intermediate_results, monitor)
#     241
#     242         LOGGER.debug("Computing %s(*%s, **%s)", task.__class__.__name__, str(inputs), str(kw_inputs))
# --> 243         return task(*inputs, **kw_inputs, monitor=monitor)
#     244
#     245     def _relax_dependencies(self, *, dependency, out_degrees, intermediate_results):
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\eolearn\core\eotask.py in __call__(self, monitor, *eopatches, **kwargs)
#      57         #     return self.execute_and_monitor(*eopatches, **kwargs)
#      58
# ---> 59         return self._execute_handling(*eopatches, **kwargs)
#      60
#      61     def execute_and_monitor(self, *eopatches, **kwargs):
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\eolearn\core\eotask.py in _execute_handling(self, *eopatches, **kwargs)
#      83                 extended_exception = exception
#      84
# ---> 85             raise extended_exception.with_traceback(traceback)
#      86
#      87     @abstractmethod
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\eolearn\core\eotask.py in _execute_handling(self, *eopatches, **kwargs)
#      70
#      71         try:
# ---> 72             return_value = self.execute(*eopatches, **kwargs)
#      73             self.private_task_config.end_time = datetime.datetime.now()
#      74             return return_value
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\eolearn\io\sentinelhub_service.py in execute(self, eopatch, bbox, time_interval)
#     202         request_params, service_type = self._prepare_request_data(eopatch, bbox, time_interval)
#     203         request = {ServiceType.WMS: WmsRequest,
# --> 204                    ServiceType.WCS: WcsRequest}[service_type](**request_params)
#     205
#     206         request_dates = request.get_dates()
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\data_request.py in __init__(self, resx, resy, **kwargs)
#     493         :type config: SHConfig or None
#     494         """
# --> 495         super().__init__(service_type=ServiceType.WCS, size_x=resx, size_y=resy, **kwargs)
#     496
#     497
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\data_request.py in __init__(self, layer, bbox, time, service_type, data_source, size_x, size_y, maxcc, image_format, custom_url_params, time_difference, **kwargs)
#     302         self.wfs_iterator = None
#     303
# --> 304         super().__init__(SentinelHubDownloadClient, **kwargs)
#     305
#     306     def _check_custom_url_parameters(self):
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\data_request.py in __init__(self, download_client_class, data_folder, config, instance_id)
#      50         self.download_list = []
#      51         self.folder_list = []
# ---> 52         self.create_request()
#      53
#      54     @abstractmethod
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\data_request.py in create_request(self, reset_wfs_iterator)
#     331
#     332         ogc_service = OgcImageService(config=self.config)
# --> 333         self.download_list = ogc_service.get_request(self)
#     334         self.wfs_iterator = ogc_service.get_wfs_iterator()
#     335
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\ogc.py in get_request(self, request)
#      83         return [DownloadRequest(url=self.get_url(request=request, date=date, size_x=size_x, size_y=size_y),
#      84                                 data_type=request.image_format, headers=SHConstants.HEADERS)
# ---> 85                 for date in self.get_dates(request)]
#      86
#      87     def get_url(self, request, *, date=None, size_x=None, size_y=None, geometry=None):
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\ogc.py in get_dates(self, request)
#     308             self.wfs_iterator = request.wfs_iterator
#     309
# --> 310         dates = self.wfs_iterator.get_dates()
#     311         dates = filter_times(dates, request.time_difference)
#     312
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\ogc.py in get_dates(self)
#     449         tile_dates = []
#     450
# --> 451         for tile_info in self:
#     452             if not tile_info['properties']['date']:  # could be True for custom (BYOC) data sources
#     453                 tile_dates.append(None)
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\ogc.py in __next__(self)
#     395         """
#     396         while self.index >= len(self.tile_list) and self.feature_offset is not None:
# --> 397             self._fetch_features()
#     398
#     399         if self.index < len(self.tile_list):
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\ogc.py in _fetch_features(self)
#     425
#     426         LOGGER.debug("URL=%s", url)
# --> 427         response = get_json(url)
#     428
#     429         is_sentinel1 = self.data_source.is_sentinel1()
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\download\client.py in get_json(url, post_values, headers, download_client_class)
#     166                               save_response=False, return_data=True, data_type=MimeType.JSON)
#     167
# --> 168     return download_client_class().download(request)
#     169
#     170
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\download\client.py in download(self, download_requests, max_threads, decode_data)
#      77                 if self.raise_download_errors:
#      78                     traceback = sys.exc_info()[2]
# ---> 79                     raise download_exception.with_traceback(traceback)
#      80
#      81                 warnings.warn(str(download_exception), category=SHRuntimeWarning)
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\download\client.py in download(self, download_requests, max_threads, decode_data)
#      73         for future in download_list:
#      74             try:
# ---> 75                 data_list.append(future.result())
#      76             except DownloadFailedException as download_exception:
#      77                 if self.raise_download_errors:
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\concurrent\futures\_base.py in result(self, timeout)
#     423                 raise CancelledError()
#     424             elif self._state == FINISHED:
# --> 425                 return self.__get_result()
#     426
#     427             self._condition.wait(timeout)
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\concurrent\futures\_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\concurrent\futures\thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\download\client.py in _single_download(self, request, decode_data)
#      98             return None
#      99
# --> 100         response_content = self._execute_download(request)
#     101
#     102         if request_path and request.save_response and (self.redownload or not os.path.exists(request_path)):
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\download\handlers.py in new_download_func(self, request)
#      42         for attempt_num in range(download_attempts):
#      43             try:
# ---> 44                 return download_func(self, request)
#      45             except requests.RequestException as exception:
#      46
#
# c:\users\frolui\appdata\local\programs\python\python37\lib\site-packages\sentinelhub\download\handlers.py in new_download_func(self, request)
#      25                 exception.response.status_code != requests.status_codes.codes.TOO_MANY_REQUESTS:
#      26
# ---> 27                 raise DownloadFailedException(_create_download_failed_message(exception, request.url)) from exception
#      28             raise exception from exception
#      29
#
# DownloadFailedException: During execution of task S2L2AWCSInput: Failed to download from:
# https://services.sentinel-hub.com/ogc/wfs/4d2333cd-27aa-43ed-9b6e-60240a6f6787?SERVICE=wfs&REQUEST=GetFeature&TYPENAMES=DSS2&BBOX=52.63%2C5.6%2C52.68%2C5.75&OUTPUTFORMAT=application%2Fjson&SRSNAME=EPSG%3A4326&TIME=2018-04-01T00%3A00%3A00%2F2018-05-01T23%3A59%3A59&MAXCC=80.0&MAXFEATURES=100&FEATURE_OFFSET=0
# with HTTPError:
# 400 Client Error: Bad Request for url: https://services.sentinel-hub.com/ogc/wfs/4d2333cd-27aa-43ed-9b6e-60240a6f6787?SERVICE=wfs&REQUEST=GetFeature&TYPENAMES=DSS2&BBOX=52.63%2C5.6%2C52.68%2C5.75&OUTPUTFORMAT=application%2Fjson&SRSNAME=EPSG%3A4326&TIME=2018-04-01T00%3A00%3A00%2F2018-05-01T23%3A59%3A59&MAXCC=80.0&MAXFEATURES=100&FEATURE_OFFSET=0
# Server response: "TYPENAME=DSS2 not found!"
